# %% [markdown]
# ### 1.Import Depedencies

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the Dataset

# %%
df = pd.read_csv('../Data/Raw/ChurnModelling.csv')
df.head()

# %% [markdown]
# ### Removing Unnecesary Columns

# %%
df.drop(columns=['RowNumber', 'CustomerId'], axis=1, inplace=True)
df.head()

# %%
df.to_csv('../Data/Processed/ChurnModelling_cleaned.csv', index=False)
