# %% [markdown]
# # 🌟 Customer Churn Analysis Report
#
# ---
#
# ## 📌 Overview
# This analysis explores patterns of customer churn using **demographic**, **behavioral**, and **product usage** data.
# The goal is to uncover **actionable insights** to improve customer retention strategies.
#
# ---
#
# ## 🔑 Key Insights
#
# ### 1️⃣ Age and Churn
# - **Middle-aged customers** are more likely to churn compared to younger customers.
# - Retention strategies should focus on the **specific needs of this age group**.
#
# **Visualization:**
# ![image.png](attachment:image.png)
#
# ---
#
# ### 2️⃣ Credit Card Ownership
# - There is **no significant difference** in churn rates between customers who **have a credit card** and those who do not.
# - Credit card ownership alone is **not a strong predictor of churn**.
#
# **Visualization:**
# ![Has Credit Card vs Exited]
# ![image-2.png](attachment:image-2.png)
#
# ---
#
# ### 3️⃣ Product Interaction
# - Customers who **interact more with the bank** (through loans, credit cards, or other products) are **less likely to churn**.
# - **Recommendation:** Increase engagement by offering **multiple products** and personalized services.
#
# **Visualization:**
# ![Product Interaction vs Churn]
# ![image-4.png](attachment:image-4.png)
#
# ---
#
# ### 4️⃣ Geography and Churn
# - Churn rates differ across countries: **Germany and France have higher churn** compared to Spain.
# - The number of churned customers in Germany and France is roughly **twice that of Spain**.
# - **Insight:** Region-specific retention strategies may be necessary.
#
# **Visualization:**
# ![Country vs Exited]
# ![image-3.png](attachment:image-3.png)
#
#
# ---
#
# ### 5️⃣ Gender and Churn
# - Analysis reveals that **females have a slightly higher churn rate** than males.
# - **Recommendation:** Tailored engagement strategies by gender can improve retention.
#
# **Visualization:**
# ![Gender vs Exited]
# ![image-5.png](attachment:image-5.png)
#
# ---
#
# ## 📈 Recommendations
# 1. **Target Middle-Age Customers:** Focus retention campaigns on the age group with higher churn.
# 2. **Enhance Product Engagement:** Encourage usage of multiple banking products to increase loyalty.
# 3. **Regional Strategies:** Develop customized strategies for countries with higher churn rates.
# 4. **Monitor Demographics:** Consider gender differences when designing retention programs.
#
# ---
#
# ## 🎨 Visualization Notes
# - Use **clear titles, labels, and legends** for all charts.
# - Include **percentage labels** where applicable to highlight key insights.
# - Maintain a **consistent color palette** across all visualizations for readability.
#
# ---
#
# *Report generated by: [Your Name / Data Analyst]*
# *Date: 2025-12-27*
